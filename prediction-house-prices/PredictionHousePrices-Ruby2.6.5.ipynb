# %%
# pycallの準備
require 'pycall/import'
include PyCall::Import
# Out:
# Object

# %%
# ライブラリのインポート
pyimport :pandas, as: :pd
pyimport 'matplotlib.pyplot', as: :plt
pyfrom 'mpl_toolkits.mplot3d', import: :Axes3D
pyimport :seaborn, as: :sns
pyimport :numpy, as: :np
pyfrom 'sklearn.linear_model', import: :LinearRegression
# Out:
# [:LinearRegression]

# %%
# 学習データの読み込み
df = pd.read_csv('./train.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape    ...     Fence MiscFeature MiscVal MoSold YrSold SaleType SaleCondition SalePrice
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg    ...       NaN         NaN       0      2   2008       WD        Normal    208500
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg    ...       NaN         NaN       0      5   2007       WD        Normal    181500
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1    ...       NaN         NaN       0      9   2008       WD        Normal    223500
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1    ...       NaN         NaN       0      2   2006       WD       Abnorml    140000
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1    ...       NaN         NaN       0     12   2008       WD        Normal    250000
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1    ...     MnPrv        Shed     700     10   2009       WD        Normal    143000
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg    ...       NaN         NaN       0      8   2007       WD        Normal    307000
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1    ...       NaN        Shed     350     11   2009       WD        Normal    200000
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg    ...       NaN         NaN       0      4   2008       WD       Abnorml    129900
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg    ...       NaN         NaN       0      1   2008       WD        Normal    118000
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg    ...       NaN         NaN       0      2   2008       WD        Normal    129500
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1    ...       NaN         NaN       0      7   2006      New       Partial    345000
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2    ...       NaN         NaN       0      9   2008       WD        Normal    144000
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1    ...       NaN         NaN       0      8   2007      New       Partial    279500
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1    ...      GdWo         NaN       0      5   2008       WD        Normal    157000
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg    ...     GdPrv         NaN       0      7   2007       WD        Normal    132000
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1    ...       NaN        Shed     700      3   2010       WD        Normal    149000
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg    ...       NaN        Shed     500     10   2006       WD        Normal     90000
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg    ...       NaN         NaN       0      6   2008       WD        Normal    159000
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg    ...     MnPrv         NaN       0      5   2009      COD       Abnorml    139000
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1    ...       NaN         NaN       0     11   2006      New       Partial    325300
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg    ...     GdPrv         NaN       0      6   2007       WD        Normal    139400
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg    ...       NaN         NaN       0      9   2008       WD        Normal    230000
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg    ...       NaN         NaN       0      6   2007       WD        Normal    129900
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1    ...     MnPrv         NaN       0      5   2010       WD        Normal    154000
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg    ...       NaN         NaN       0      7   2009       WD        Normal    256300
# 26      27          20       RL         60.0     7200   Pave   NaN      Reg    ...       NaN         NaN       0      5   2010       WD        Normal    134800
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg    ...       NaN         NaN       0      5   2010       WD        Normal    306000
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1    ...       NaN         NaN       0     12   2006       WD        Normal    207500
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1    ...       NaN         NaN       0      5   2008       WD        Normal     68500
# ...    ...         ...      ...          ...      ...    ...   ...      ...    ...       ...         ...     ...    ...    ...      ...           ...       ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3    ...       NaN         NaN       0      7   2006       WD        Normal    192140
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1    ...       NaN         NaN       0     10   2009       WD        Normal    143750
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg    ...       NaN         NaN       0      8   2007       WD        Normal     64500
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1    ...       NaN         NaN       0      5   2008       WD        Normal    186500
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg    ...       NaN         NaN       0      5   2006       WD        Normal    160000
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg    ...     GdPrv         NaN       0      7   2008      COD       Abnorml    174000
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg    ...      GdWo         NaN       0      5   2007       WD        Normal    120500
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg    ...       NaN         NaN       0     11   2008      New       Partial    394617
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg    ...     MnPrv         NaN       0      4   2010       WD        Normal    149700
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg    ...       NaN         NaN       0     11   2007       WD        Normal    197000
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1    ...       NaN         NaN       0      9   2008       WD        Normal    191000
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg    ...       NaN         NaN       0      5   2008       WD        Normal    149300
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg    ...       NaN         NaN       0      4   2009       WD        Normal    310000
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg    ...       NaN         NaN       0      5   2009       WD        Normal    121000
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg    ...       NaN         NaN       0     11   2007       WD        Normal    179600
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg    ...       NaN         NaN       0      5   2007       WD        Normal    129000
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1    ...       NaN         NaN       0      4   2010       WD        Normal    157900
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg    ...       NaN         NaN       0     12   2007       WD        Normal    240000
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg    ...      GdWo         NaN       0      5   2007       WD        Normal    112000
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg    ...       NaN         NaN       0      8   2006       WD       Abnorml     92000
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg    ...       NaN         NaN       0      9   2009       WD        Normal    136000
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg    ...       NaN         NaN       0      5   2009      New       Partial    287090
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg    ...       NaN         NaN       0      5   2006       WD        Normal    145000
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg    ...       NaN         NaN       0      7   2006       WD       Abnorml     84500
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg    ...       NaN         NaN       0     10   2009       WD        Normal    185000
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg    ...       NaN         NaN       0      8   2007       WD        Normal    175000
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg    ...     MnPrv         NaN       0      2   2010       WD        Normal    210000
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg    ...     GdPrv        Shed    2500      5   2010       WD        Normal    266500
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg    ...       NaN         NaN       0      4   2010       WD        Normal    142125
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg    ...       NaN         NaN       0      6   2008       WD        Normal    147500
#
# [1460 rows x 81 columns]

# %%
# 学習データ（先頭5行）の内容を確認
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour    ...     PoolQC Fence MiscFeature MiscVal MoSold YrSold SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg         Lvl    ...        NaN   NaN         NaN       0      2   2008       WD        Normal     208500
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg         Lvl    ...        NaN   NaN         NaN       0      5   2007       WD        Normal     181500
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1         Lvl    ...        NaN   NaN         NaN       0      9   2008       WD        Normal     223500
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1         Lvl    ...        NaN   NaN         NaN       0      2   2006       WD       Abnorml     140000
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1         Lvl    ...        NaN   NaN         NaN       0     12   2008       WD        Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### 重回帰分析での予測

# %%
# XにOverallQualとGrLivArea、yにSalePriceをセット
X = []
X << PyCall::List.(df['OverallQual'].values).to_a
X << PyCall::List.(df['GrLivArea'].values).to_a
y = df['SalePrice'].values

# アルゴリズムに線形回帰（Linear Regression)を採用
slr = LinearRegression.new

# fit関数で学習開始
slr.fit(X.transpose, y)

# 偏回帰係数（回帰分析において得られる回帰方程式の各説明変数の係数）を出力
# 偏回帰係数はscikit-learnのcoefで取得
#print('傾き：{0}'.format(slr.coef_))
puts "傾き：#{slr.coef_}"
a1, a2 = slr.coef_[0], slr.coef_[1]

# y切片（直線とy軸との交点）を出力
#print('y切片：{0}'.format(slr.intercept_))
puts "y切片：#{slr.intercept_}"
b = slr.intercept_
# Out:
# 傾き：[32849.04744063    55.86222591]
# y切片：-104092.66963598106
# -104092.66963598106

# %%
# 3D描画（散布図の描画）
x, y, z = np.array(df['OverallQual']), np.array(df['GrLivArea']), np.array(df['SalePrice'].values)
fig = plt.figure()
ax = Axes3D.new(fig)
ax.scatter3D(np.ravel(x), np.ravel(y), np.ravel(z))

# 3D描画（回帰平面の描画）
# np.arange(0, 10, 2)は初項0, 公差2で終点が10の等差数列（array([2, 4, 6, 8, 10])
X, Y = np.meshgrid(np.arange(0, 12, 2), np.arange(0, 6000, 1000))
Z = a1 * X + a2 * Y + b
ax.plot_surface(X, Y, Z, alpha: 0.5, color: 'red') # alphaで透明度を指定
ax.set_xlabel('OverallQual')
ax.set_ylabel('GrLivArea')
ax.set_zlabel('SalePrice')

# グラフを画像として保存
plt.savefig('figure.svg')
plt.close()

# 保存されたグラフの画像を読み込む
open('figure.svg')
# Out:
# <main>:8: warning: already initialized constant X
# <main>:1: warning: previous definition of X was here
# #<File:figure.svg>

# %%
# テストデータの読み込み
df_test = pd.read_csv('./test.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape      ...      PoolQC  Fence MiscFeature MiscVal MoSold YrSold SaleType SaleCondition
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg      ...         NaN  MnPrv         NaN       0      6   2010       WD        Normal
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1      ...         NaN    NaN        Gar2   12500      6   2010       WD        Normal
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1      ...         NaN  MnPrv         NaN       0      3   2010       WD        Normal
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      1   2010       WD        Normal
# 5     1466          60       RL         75.0    10000   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      4   2010       WD        Normal
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1      ...         NaN  GdPrv        Shed     500      3   2010       WD        Normal
# 7     1468          60       RL         63.0     8402   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      5   2010       WD        Normal
# 8     1469          20       RL         85.0    10176   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      2   2010       WD        Normal
# 9     1470          20       RL         70.0     8400   Pave   NaN      Reg      ...         NaN  MnPrv         NaN       0      4   2010       WD        Normal
# 10    1471         120       RH         26.0     5858   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 11    1472         160       RM         21.0     1680   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      2   2010      COD        Normal
# 12    1473         160       RM         21.0     1680   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      3   2010       WD        Normal
# 13    1474         160       RL         24.0     2280   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 14    1475         120       RL         24.0     2280   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 15    1476          60       RL        102.0    12858   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      1   2010      New       Partial
# 16    1477          20       RL         94.0    12883   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      6   2010      New       Partial
# 17    1478          20       RL         90.0    11520   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 18    1479          20       RL         79.0    14122   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      2   2010       WD        Normal
# 19    1480          20       RL        110.0    14300   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 20    1481          60       RL        105.0    13650   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 21    1482         120       RL         41.0     7132   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      4   2010       WD        Normal
# 22    1483          20       RL        100.0    18494   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      1   2010       WD        Normal
# 23    1484         120       RL         43.0     3203   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      1   2010       WD        Normal
# 24    1485          80       RL         67.0    13300   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 25    1486          60       RL         63.0     8577   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      4   2010       WD        Normal
# 26    1487          60       RL         60.0    17433   Pave   NaN      IR2      ...         NaN    NaN         NaN       0      1   2010       WD        Normal
# 27    1488          20       RL         73.0     8987   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2010       WD        Normal
# 28    1489          20       FV         92.0     9215   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      4   2010      New       Partial
# 29    1490          20       FV         84.0    10440   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2010       WD        Normal
# ...    ...         ...      ...          ...      ...    ...   ...      ...      ...         ...    ...         ...     ...    ...    ...      ...           ...
# 1429  2890          30       RM         50.0     7030   Pave   NaN      Reg      ...         NaN  MnPrv         NaN       0      3   2006       WD        Normal
# 1430  2891          50       RM         75.0     9060   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      4   2006       WD        Normal
# 1431  2892          30  C (all)         69.0    12366   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     10   2006       WD       Abnorml
# 1432  2893         190  C (all)         50.0     9000   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     10   2006       WD       Abnorml
# 1433  2894          50  C (all)         60.0     8520   Grvl   NaN      Reg      ...         NaN    NaN         NaN       0      4   2006       WD        Normal
# 1434  2895         120       RM         41.0     5748   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      2   2006      New       Partial
# 1435  2896         120       RM         44.0     3842   Pave   NaN      IR1      ...         NaN    NaN         NaN       0     12   2006       WD        Normal
# 1436  2897          20       RL         69.0    23580   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      9   2006       WD        Normal
# 1437  2898          90       RL         65.0     8385   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     10   2006       WD        Normal
# 1438  2899          20       RL         70.0     9116   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2006       WD        Normal
# 1439  2900          80       RL        140.0    11080   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2006       WD        Normal
# 1440  2901          20       RL          NaN    50102   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      3   2006       WD        Alloca
# 1441  2902          20       RL          NaN     8098   Pave   NaN      IR1      ...         NaN    NaN         NaN       0     10   2006       WD        Normal
# 1442  2903          20       RL         95.0    13618   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     11   2006      New       Partial
# 1443  2904          20       RL         88.0    11577   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      9   2006      New       Partial
# 1444  2905          20      NaN        125.0    31250   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2006       WD        Normal
# 1445  2906          90       RM         78.0     7020   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     11   2006       WD        Normal
# 1446  2907         160       RM         41.0     2665   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2006       WD        Normal
# 1447  2908          20       RL         58.0    10172   Pave   NaN      IR1      ...         NaN    NaN         NaN       0     10   2006       WD        Normal
# 1448  2909          90       RL          NaN    11836   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      3   2006       WD        Normal
# 1449  2910         180       RM         21.0     1470   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      4   2006       WD        Normal
# 1450  2911         160       RM         21.0     1484   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2006       WD        Normal
# 1451  2912          20       RL         80.0    13384   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      5   2006       WD        Normal
# 1452  2913         160       RM         21.0     1533   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     12   2006       WD       Abnorml
# 1453  2914         160       RM         21.0     1526   Pave   NaN      Reg      ...         NaN  GdPrv         NaN       0      6   2006       WD        Normal
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      6   2006       WD        Normal
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      4   2006       WD       Abnorml
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg      ...         NaN    NaN         NaN       0      9   2006       WD       Abnorml
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg      ...         NaN  MnPrv        Shed     700      7   2006       WD        Normal
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg      ...         NaN    NaN         NaN       0     11   2006       WD        Normal
#
# [1459 rows x 80 columns]

# %%
# テストデータの内容確認
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape      ...      PoolQC  Fence MiscFeature MiscVal MoSold YrSold SaleType SaleCondition
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg      ...         NaN  MnPrv         NaN       0      6   2010       WD        Normal
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1      ...         NaN    NaN        Gar2   12500      6   2010       WD        Normal
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1      ...         NaN  MnPrv         NaN       0      3   2010       WD        Normal
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      6   2010       WD        Normal
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1      ...         NaN    NaN         NaN       0      1   2010       WD        Normal
#
# [5 rows x 80 columns]

# %%
# テストデータのOverallQualとGrLivAreaの値をセット
X_test = []
X_test << PyCall::List.(df_test['OverallQual'].values).to_a
X_test << PyCall::List.(df_test['GrLivArea'].values).to_a

# 学習済みのモデルから予測した結果をセット
y_test_pred = slr.predict(X_test.transpose)
# Out:
# array([110205.12197947, 167242.51323765, 151152.13356901, ...,
#        128527.93207683, 114338.92669655, 237575.11426161])

# %%
# 学習済みのモデルから予測した結果を出力
y_test_pred
# Out:
# array([110205.12197947, 167242.51323765, 151152.13356901, ...,
#        128527.93207683, 114338.92669655, 237575.11426161])
